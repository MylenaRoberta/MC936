# %% [markdown]
# ### Importar Bibliotecas utilizadas

# %%
import math
import pandas as pd
import glob

# Conectando ao Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

PATH = '/content/drive/MyDrive/MC936/P2/data/processed/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Abrir os arquivos com os dados dos cenários e selecionar os pacientes que morreram por COVID-19

# %%
query = "scenario*_clustering.csv"
SCS_PATHS = glob.glob(PATH+query)
# print(SCS_PATHS)
SCS_DFS = list(map(lambda csv_path: pd.read_csv(csv_path), SCS_PATHS))
# Selecionar pacientes que morreram por COVID-19 em até 30 dias
DIED_DFS = list(map(lambda df: df.loc[df['DIED IN ONE MONTH'] == 1].copy(), SCS_DFS))

# %% [markdown]
# ### Definição das Características dos grupos de Risco

# %%
risk_group = list()

# COVID Related
risk_group.append('DIED IN ONE MONTH')
risk_group.append('COVID-19')
risk_group.append('Face mask (physical object)')
risk_group.append('SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose')
risk_group.append('SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose')
risk_group.append('SARS-COV-2 (COVID-19) vaccine  vector non-replicating  recombinant spike protein-Ad26  preservative free  0.5 mL')
risk_group.append('Suspected COVID-19')

# High blood pressure
risk_group.append('Hypertension')

# Heart problems
risk_group.append('Cardiac Arrest')
risk_group.append('Coronary Heart Disease')
risk_group.append('Heart failure (disorder)')
risk_group.append('Heart failure education (procedure)')
risk_group.append('History of cardiac arrest (situation)')
risk_group.append('History of myocardial infarction (situation)')
risk_group.append('Injury of heart (disorder)')
risk_group.append('Myocardial Infarction')

# Lung problems
risk_group.append('Acute bronchitis (disorder)')
risk_group.append('Acute pulmonary embolism (disorder)')
risk_group.append('Acute respiratory distress syndrome (disorder)')
risk_group.append('Acute respiratory failure (disorder)')
risk_group.append('Childhood asthma')
risk_group.append('Chronic obstructive bronchitis (disorder)')
risk_group.append('Lung volume reduction surgery (procedure)')
risk_group.append('Oxygen administration by mask (procedure)')
risk_group.append('Pulmonary emphysema (disorder)')
risk_group.append('Pulmonary rehabilitation (regime/therapy)')
risk_group.append('Respiratory distress (finding)')

# Diabetes
risk_group.append('Diabetes')
risk_group.append('Diabetic renal disease (disorder)')
risk_group.append('Diabetic retinopathy associated with type II diabetes mellitus (disorder)')
risk_group.append('Hyperglycemia (disorder)')
risk_group.append('Prediabetes')

# Obesity
risk_group.append('Body mass index 30+ - obesity (finding)')
risk_group.append('Body mass index 40+ - severely obese (finding)')

# Cancer
risk_group.append('Acute myeloid leukemia  disease (disorder)')
risk_group.append('Carcinoma in situ of prostate (disorder)')
risk_group.append('Chemotherapy (procedure)')
risk_group.append('Febrile neutropenia (disorder)')
risk_group.append('Malignant neoplasm of breast (disorder)')
risk_group.append('Malignant tumor of colon')
risk_group.append('Neoplasm of prostate')
risk_group.append('Neutropenia (disorder)')
risk_group.append('Overlapping malignant neoplasm of colon')

not_present = ['Heart failure education (procedure)',
 'History of myocardial infarction (situation)',
 'Myocardial Infarction',
 'Diabetic retinopathy associated with type II diabetes mellitus (disorder)',
 'Carcinoma in situ of prostate (disorder)',
 'Malignant tumor of colon',
 'Neoplasm of prostate']

risk_group.remove('COVID-19')
new_risk_group = list()
for x in risk_group:
  if x not in not_present:
    new_risk_group.append(x)

others = ['AGE', 'PATIENT', 'RACE',
                   'ETHNICITY', 'GENDER', 'CITY', 'STATE', 'Cluster' ]

print(new_risk_group)

# %% [markdown]
# ### Selecionar as colunas relacionadas as características dos grupos de risco

# %%
scenario01_02_rfc = list(map(lambda df: df[new_risk_group+others].copy(), [DIED_DFS[0], DIED_DFS[1]]))
scenario03_rfc = list(map(lambda df: df[risk_group+others].copy(), [DIED_DFS[2], DIED_DFS[3]]))

# %% [markdown]
# ### Criar para cada paciente em cada DataFrame uma das características do grupo de risco que ele apresenta, bem como outras caracteristicas como idade e sexo

# %%
def get_features(row, features:list):
  lfs = list()
  for feature in features:
    if row[feature] == 1:
      lfs.append(feature)

  return lfs

def get_patients(df:pd.DataFrame, features: list):
  df.reset_index()
  p_dict = dict()
  for index, row in df.iterrows():
    p_dict[row['PATIENT']] = get_features(row, features)
    p_dict[row['PATIENT']] += [row['AGE'], row['Cluster'],
                              row['GENDER'], row['ETHNICITY']]

  return p_dict

# %%
scenario01_02_rfc = list(map(lambda x: get_patients(x, new_risk_group), scenario01_02_rfc))
scenario03_rfc = list(map(lambda x: get_patients(x, risk_group), scenario03_rfc))

# %% [markdown]
# ### Imprimir para cada Dataframe a lista de pacientes com suas respectivas características

# %%
print("### Clusterização Hierárquica cenário 01+02\n")
for patient, data in scenario01_02_rfc[0].items():
  print(f'Informações do Paciente **{patient}** :')
  for value in data:
    print(f'- {value}')
  print()
# Out:
# ### Clusterização Hierárquica cenário 01+02
#
# Informações do Paciente **9ec0c1c1-724e-135d-aa6d-bd0779e31c44** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose
# - Suspected COVID-19
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Lung volume reduction surgery (procedure)
# - Oxygen administration by mask (procedure)
# - Pulmonary emphysema (disorder)
# - Pulmonary rehabilitation (regime/therapy)
# - Respiratory distress (finding)
# - 72.0
# - C7
# - M
# - nonhispanic
#
# Informações do Paciente **d1e4b72c-3916-e04f-cfb7-8e97f3c7e4b7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 66.0
# - C7
# - F
# - nonhispanic
#
# Informações do Paciente **7d952845-19f9-f87c-2d37-662d765fa7e2** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Prediabetes
# - 104.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **94fc2c74-6f80-69b3-5c92-933070145cb7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 104.0
# - C3
# - M
# - nonhispanic
#
# Informações do Paciente **9d24509c-42e9-b71a-6466-fbe64f52855c** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 75.0
# - C7
# - F
# - nonhispanic
#
# Informações do Paciente **1b46a593-3b14-53dd-1d2b-b59866e09a18** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Cardiac Arrest
# - Coronary Heart Disease
# - Heart failure (disorder)
# - History of cardiac arrest (situation)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 89.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **f3bfc742-ea46-4bcd-b901-31182f21cfdf** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Hyperglycemia (disorder)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 56.0
# - C7
# - M
# - nonhispanic
#
# Informações do Paciente **c157e973-3a07-ef2b-cced-01eea3351ccd** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 84.0
# - C3
# - F
# - nonhispanic

# %%
print("### Clusterização K-Means cenário 01+02\n")
for patient, data in scenario01_02_rfc[1].items():
  print(f'Informações do Paciente **{patient}** :')
  for value in data:
    print(f'- {value}')
  print()
# Out:
# ### Clusterização K-Means cenário 01+02
#
# Informações do Paciente **9ec0c1c1-724e-135d-aa6d-bd0779e31c44** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose
# - Suspected COVID-19
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Lung volume reduction surgery (procedure)
# - Oxygen administration by mask (procedure)
# - Pulmonary emphysema (disorder)
# - Pulmonary rehabilitation (regime/therapy)
# - Respiratory distress (finding)
# - 72.0
# - C1
# - M
# - nonhispanic
#
# Informações do Paciente **d1e4b72c-3916-e04f-cfb7-8e97f3c7e4b7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 66.0
# - C5
# - F
# - nonhispanic
#
# Informações do Paciente **7d952845-19f9-f87c-2d37-662d765fa7e2** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Prediabetes
# - 104.0
# - C5
# - M
# - nonhispanic
#
# Informações do Paciente **94fc2c74-6f80-69b3-5c92-933070145cb7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 104.0
# - C5
# - M
# - nonhispanic
#
# Informações do Paciente **9d24509c-42e9-b71a-6466-fbe64f52855c** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 75.0
# - C5
# - F
# - nonhispanic
#
# Informações do Paciente **1b46a593-3b14-53dd-1d2b-b59866e09a18** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Cardiac Arrest
# - Coronary Heart Disease
# - Heart failure (disorder)
# - History of cardiac arrest (situation)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 89.0
# - C3
# - M
# - nonhispanic
#
# Informações do Paciente **f3bfc742-ea46-4bcd-b901-31182f21cfdf** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Hyperglycemia (disorder)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 56.0
# - C5
# - M
# - nonhispanic
#
# Informações do Paciente **c157e973-3a07-ef2b-cced-01eea3351ccd** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Malignant neoplasm of breast (disorder)
# - 84.0
# - C5
# - F
# - nonhispanic

# %%
print("### Clusterização Hierárquica cenário 03\n")
for patient, data in scenario03_rfc[0].items():
  print(f'Informações do Paciente **{patient}** :')
  for value in data:
    print(f'- {value}')
  print()
# Out:
# ### Clusterização Hierárquica cenário 03
#
# Informações do Paciente **70d44a6a-1359-fd33-3447-f3cb0942a2ce** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 104.0
# - C2
# - F
# - hispanic
#
# Informações do Paciente **de51c590-ed3f-c764-3001-57a3001b0f43** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic retinopathy associated with type II diabetes mellitus (disorder)
# - Hyperglycemia (disorder)
# - Prediabetes
# - 70.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **7a97a805-d262-e64a-bca9-648a0ad993d4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose
# - Suspected COVID-19
# - Coronary Heart Disease
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 74.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **e7f609f6-8d97-ffcd-1352-73e9ce93144f** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Chronic obstructive bronchitis (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 64.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **661e6f70-018c-fb12-16cc-f676af49f4b4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Chronic obstructive bronchitis (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 62.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **65977a4c-5d3a-3ba0-ec76-83726c4a07c3** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 66.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **9e7f2a13-c352-ded5-dd00-e37cafff8fee** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Hyperglycemia (disorder)
# - Prediabetes
# - 72.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **ea939a6f-5094-61de-06f3-ba207d408863** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 83.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **5c94440c-fc88-d57f-360d-afffa733fee7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Heart failure (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Malignant tumor of colon
# - 62.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **7a217574-9ca5-6499-bedb-598540186fdc** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 66.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **d045e438-1ffc-dda7-9722-50a388a39742** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 62.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **738a0f31-b738-e95e-3527-ed0242a7faee** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 74.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **08ae0892-52f4-3d76-58c4-3ab3e247ad86** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 53.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **b42b3537-105a-bcf6-d209-682fcab920b4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 61.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **c912f42f-9e53-3d62-0621-df9c41bdbbf3** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 78.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **9228d4dd-610f-7855-5a89-1559cab61d4d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 47.0
# - C1
# - F
# - nonhispanic
#
# Informações do Paciente **c0f03f66-e415-b749-8e91-54ca9fa3b928** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose
# - Suspected COVID-19
# - Hypertension
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 108.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **75ca0542-ae44-0cea-993d-bd3b1ae132c4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 79.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **147573da-1d3f-20be-d5b4-861de0d6d7b2** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose
# - Suspected COVID-19
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 75.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **2809af1f-445f-9792-8934-8943b7a3091d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Cardiac Arrest
# - Heart failure (disorder)
# - History of cardiac arrest (situation)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 81.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **a084afca-26e6-a0c8-a1a6-77a06bd016b0** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 57.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **eea26a1d-59dc-8795-a046-2c6dbc1af817** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Diabetic retinopathy associated with type II diabetes mellitus (disorder)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 99.0
# - C4
# - M
# - nonhispanic
#
# Informações do Paciente **9bf2d02d-3ac8-9bd1-f2ef-c2a4dc4e1a18** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 83.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **cdd4f6b9-b8ab-c457-a0b7-87b579f9165d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - Overlapping malignant neoplasm of colon
# - 65.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **0cfeb83b-7945-7225-4311-b4c122128948** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 100.0
# - C4
# - M
# - hispanic
#
# Informações do Paciente **3ab21167-968a-f227-0c9b-e208034fccb5** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Acute myeloid leukemia  disease (disorder)
# - Chemotherapy (procedure)
# - Febrile neutropenia (disorder)
# - 23.0
# - C4
# - M
# - hispanic
#
# Informações do Paciente **9c5c9eff-945c-597d-60fd-3f7f0f6fce2c** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 53.0
# - C1
# - F
# - nonhispanic
#
# Informações do Paciente **b542b442-c7b8-fcea-61b8-e2f7dd0afa03** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Cardiac Arrest
# - Coronary Heart Disease
# - History of cardiac arrest (situation)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 72.0
# - C4
# - M
# - hispanic
#
# Informações do Paciente **42c3b05e-84af-cade-c9cf-822e649ccd50** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Body mass index 40+ - severely obese (finding)
# - 65.0
# - C4
# - F
# - nonhispanic
#
# Informações do Paciente **18ac2f60-222a-1c32-ebca-0fb731303105** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Acute myeloid leukemia  disease (disorder)
# - Chemotherapy (procedure)
# - Febrile neutropenia (disorder)
# - 28.0
# - C1
# - F
# - nonhispanic
#
# Informações do Paciente **5e9e1a47-5dbe-4f22-0102-fcd13bda6b4f** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - 54.0
# - C4
# - M
# - nonhispanic

# %%
print("### Clusterização K-Means cenário 03\n")
for patient, data in scenario03_rfc[1].items():
  print(f'Informações do Paciente **{patient}** :')
  for value in data:
    print(f'- {value}')
  print()
# Out:
# ### Clusterização K-Means cenário 03
#
# Informações do Paciente **70d44a6a-1359-fd33-3447-f3cb0942a2ce** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 104.0
# - C2
# - F
# - hispanic
#
# Informações do Paciente **de51c590-ed3f-c764-3001-57a3001b0f43** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic retinopathy associated with type II diabetes mellitus (disorder)
# - Hyperglycemia (disorder)
# - Prediabetes
# - 70.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **7a97a805-d262-e64a-bca9-648a0ad993d4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose
# - Suspected COVID-19
# - Coronary Heart Disease
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 74.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **e7f609f6-8d97-ffcd-1352-73e9ce93144f** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Chronic obstructive bronchitis (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 64.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **661e6f70-018c-fb12-16cc-f676af49f4b4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Chronic obstructive bronchitis (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 62.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **65977a4c-5d3a-3ba0-ec76-83726c4a07c3** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 66.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **9e7f2a13-c352-ded5-dd00-e37cafff8fee** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Hyperglycemia (disorder)
# - Prediabetes
# - 72.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **ea939a6f-5094-61de-06f3-ba207d408863** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 83.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **5c94440c-fc88-d57f-360d-afffa733fee7** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Heart failure (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Malignant tumor of colon
# - 62.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **7a217574-9ca5-6499-bedb-598540186fdc** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 66.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **d045e438-1ffc-dda7-9722-50a388a39742** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 62.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **738a0f31-b738-e95e-3527-ed0242a7faee** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 74.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **08ae0892-52f4-3d76-58c4-3ab3e247ad86** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 53.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **b42b3537-105a-bcf6-d209-682fcab920b4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 61.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **c912f42f-9e53-3d62-0621-df9c41bdbbf3** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 78.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **9228d4dd-610f-7855-5a89-1559cab61d4d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 47.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **c0f03f66-e415-b749-8e91-54ca9fa3b928** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose
# - Suspected COVID-19
# - Hypertension
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 108.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **75ca0542-ae44-0cea-993d-bd3b1ae132c4** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 79.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **147573da-1d3f-20be-d5b4-861de0d6d7b2** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  100 mcg/0.5mL dose
# - Suspected COVID-19
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 75.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **2809af1f-445f-9792-8934-8943b7a3091d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Cardiac Arrest
# - Heart failure (disorder)
# - History of cardiac arrest (situation)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 81.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **a084afca-26e6-a0c8-a1a6-77a06bd016b0** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - 57.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **eea26a1d-59dc-8795-a046-2c6dbc1af817** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Diabetes
# - Diabetic renal disease (disorder)
# - Diabetic retinopathy associated with type II diabetes mellitus (disorder)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 99.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **9bf2d02d-3ac8-9bd1-f2ef-c2a4dc4e1a18** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Coronary Heart Disease
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 83.0
# - C2
# - M
# - nonhispanic
#
# Informações do Paciente **cdd4f6b9-b8ab-c457-a0b7-87b579f9165d** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Heart failure (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - Overlapping malignant neoplasm of colon
# - 65.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **0cfeb83b-7945-7225-4311-b4c122128948** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Coronary Heart Disease
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - 100.0
# - C2
# - M
# - hispanic
#
# Informações do Paciente **3ab21167-968a-f227-0c9b-e208034fccb5** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Heart failure (disorder)
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Acute myeloid leukemia  disease (disorder)
# - Chemotherapy (procedure)
# - Febrile neutropenia (disorder)
# - 23.0
# - C2
# - M
# - hispanic
#
# Informações do Paciente **9c5c9eff-945c-597d-60fd-3f7f0f6fce2c** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Hypertension
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 53.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **b542b442-c7b8-fcea-61b8-e2f7dd0afa03** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Cardiac Arrest
# - Coronary Heart Disease
# - History of cardiac arrest (situation)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Prediabetes
# - Body mass index 30+ - obesity (finding)
# - 72.0
# - C2
# - M
# - hispanic
#
# Informações do Paciente **42c3b05e-84af-cade-c9cf-822e649ccd50** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Body mass index 30+ - obesity (finding)
# - Body mass index 40+ - severely obese (finding)
# - 65.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **18ac2f60-222a-1c32-ebca-0fb731303105** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Acute pulmonary embolism (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - Acute myeloid leukemia  disease (disorder)
# - Chemotherapy (procedure)
# - Febrile neutropenia (disorder)
# - 28.0
# - C2
# - F
# - nonhispanic
#
# Informações do Paciente **5e9e1a47-5dbe-4f22-0102-fcd13bda6b4f** :
# - DIED IN ONE MONTH
# - Face mask (physical object)
# - Suspected COVID-19
# - Injury of heart (disorder)
# - Acute bronchitis (disorder)
# - Acute pulmonary embolism (disorder)
# - Acute respiratory distress syndrome (disorder)
# - Acute respiratory failure (disorder)
# - Oxygen administration by mask (procedure)
# - Respiratory distress (finding)
# - 54.0
# - C2
# - M
# - nonhispanic
